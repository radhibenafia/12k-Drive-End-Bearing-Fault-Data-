# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# TRAVAIL SUR IR007_0 (INNER BALL)

# %%
import scipy.io
from pprint import pprint
import json

# %%
mat_file_path = '/content/drive/MyDrive/projet-sem/12k Drive End Bearing Fault Data/IR007_0.mat'

# Load the MATLAB file
mat_contents = scipy.io.loadmat(mat_file_path)

# Pretty-print the contents
print("Contents of the MATLAB file:")
pprint(mat_contents)
# Out:
# Contents of the MATLAB file:
# {'X105RPM': array([[1797]], dtype=uint16),
#  'X105_BA_time': array([[ 0.06466148],
#        [-0.02309626],
#        [-0.08852226],
#        ...,
#        [ 0.09648926],
#        [ 0.08405591],
#        [-0.02015893]]),
#  'X105_DE_time': array([[-0.08300435],
#        [-0.19573433],
#        [ 0.23341928],
#        ...,
#        [-0.31642363],
#        [-0.06367457],
#        [ 0.26736822]]),
#  'X105_FE_time': array([[-0.40207455],
#        [-0.00472545],
#        [-0.10663091],
#        ...,
#        [ 0.31598909],
#        [ 0.35091636],
#        [ 0.03307818]]),
#  '__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Mon Jan 31'
#                b' 13:49:59 2000',
#  '__version__': '1.0'}

# %% [markdown]
# Capteur BA -------------------------------------------------------------------------------------------

# %%
import numpy as np

# Access the 'X146_BA_time' variable
ba_time_data = mat_contents['X105_BA_time']

# Flatten the 2D array into a 1D numerical series
ba_time_series = np.ravel(ba_time_data)

# Print the numerical series
print("X146_BA_time series:")
print(ba_time_series)
# Out:
# X146_BA_time series:
# [ 0.06466148 -0.02309626 -0.08852226 ...  0.09648926  0.08405591
#  -0.02015893]

# %%
import matplotlib.pyplot as plt

# Assuming you have already defined ba_time_series as described in the previous response

# Plot the numerical series
plt.figure(figsize=(10, 6))
plt.plot(ba_time_series)
plt.title('X146_BA_time Numerical Series')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already defined ba_time_series as described in the previous response

# Parameters
sampling_frequency = 51.2e3  # 51.2 kHz
sampling_period = 1 / sampling_frequency  # 0.0000195313s
window_size = 2048
# Calculate the total time of the signal
total_time = len(ba_time_series) * sampling_period

# Create time array
time_array = np.arange(0, total_time, sampling_period)

# Plot each segment in red
plt.figure(figsize=(14, 6))
for i in range(0, len(ba_time_series), window_size):
    segment_time = time_array[i:i + window_size]
    segment = ba_time_series[i:i + window_size]
    plt.plot(segment_time, segment)

plt.title('Signal Segmentation with Window Size of 2048 pts')
plt.xlabel('Time (s)')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %% [markdown]
# CAPTEUR FE----------------------------------------------------------------------------------------------------------

# %%
import numpy as np

# Access the 'X146_BA_time' variable
fe_time_data = mat_contents['X105_FE_time']

# Flatten the 2D array into a 1D numerical series
fe_time_series = np.ravel(fe_time_data)

# Print the numerical series
print("X146_fe_time series:")
print(fe_time_series)
# Out:
# X146_fe_time series:
# [-0.40207455 -0.00472545 -0.10663091 ...  0.31598909  0.35091636
#   0.03307818]

# %%
import matplotlib.pyplot as plt

# Assuming you have already defined ba_time_series as described in the previous response

# Plot the numerical series
plt.figure(figsize=(10, 6))
plt.plot(fe_time_series)
plt.title('X146_FE_time Numerical Series')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already defined fe_time_series as described in the previous response

# Parameters
sampling_frequency = 51.2e3  # 51.2 kHz
sampling_period = 1 / sampling_frequency  # 0.0000195313s
window_size = 2048
# Calculate the total time of the signal
total_time = len(fe_time_series) * sampling_period

# Create time array
time_array = np.arange(0, total_time, sampling_period)

# Plot each segment in red
plt.figure(figsize=(14, 6))
for i in range(0, len(fe_time_series), window_size):
    segment_time = time_array[i:i + window_size]
    segment = fe_time_series[i:i + window_size]
    plt.plot(segment_time, segment)

plt.title('Signal Segmentation with Window Size of 2048 pts')
plt.xlabel('Time (s)')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %% [markdown]
# CAPTEUR DE -------------------------------------------------------------------------------------

# %%
import numpy as np

# Access the 'X146_BA_time' variable
de_time_data = mat_contents['X105_DE_time']

# Flatten the 2D array into a 1D numerical series
de_time_series = np.ravel(ba_time_data)

# Print the numerical series
print("X146_DE_time series:")
print(de_time_series)
# Out:
# X146_DE_time series:
# [-0.08300435 -0.19573433  0.23341928 ... -0.31642363 -0.06367457
#   0.26736822]

# %%
import matplotlib.pyplot as plt

# Assuming you have already defined ba_time_series as described in the previous response

# Plot the numerical series
plt.figure(figsize=(10, 6))
plt.plot(ba_time_series)
plt.title('X146_DE_time Numerical Series')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already defined de_time_series as described in the previous response

# Parameters
sampling_frequency = 51.2e3  # 51.2 kHz
sampling_period = 1 / sampling_frequency  # 0.0000195313s
window_size = 2048
# Calculate the total time of the signal
total_time = len(de_time_series) * sampling_period

# Create time array
time_array = np.arange(0, total_time, sampling_period)

# Plot each segment in red
plt.figure(figsize=(14, 6))
for i in range(0, len(de_time_series), window_size):
    segment_time = time_array[i:i + window_size]
    segment = de_time_series[i:i + window_size]
    plt.plot(segment_time, segment)

plt.title('Signal Segmentation with Window Size of 2048 pts')
plt.xlabel('Time (s)')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %% [markdown]
# FONCTION DE SEGMENTATION PARAMETRE CHEMEIN D'ACCES ET TYPE CAPTEUR BA,FE,DE classe 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from pprint import pprint

def plot_segmentation_from_mat(mat_file_path, substitution_type, classification):
    # Load the MATLAB file
    mat_contents = scipy.io.loadmat(mat_file_path)
    sub = substitution_type.upper()

    # Map classification to variable number
    if classification == 0:
        var_number = 105
    elif classification == 1:
        var_number = 106
    elif classification == 2:
        var_number = 107
    elif classification == 3:
        var_number = 108
    else:
        raise ValueError("Invalid classification. Supported values are 0, 1, 2, or 3.")

    # Access the variable using the substitution type and classification
    variable_name = f'X{var_number}_{sub}_time'
    time_data = mat_contents[variable_name]

    # Flatten the 2D array into a 1D numerical series
    time_series = np.ravel(time_data)

    # Print the numerical series
    print(f"{variable_name} series:")
    print(time_series)

    plt.figure(figsize=(10, 6))
    plt.plot(time_series)
    plt.title(f'{variable_name} Numerical Series')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

    # Parameters
    sampling_frequency = 51.2e3  # 51.2 kHz
    sampling_period = 1 / sampling_frequency  # 0.0000195313s
    window_size = 2048
    # Calculate the total time of the signal
    total_time = len(time_series) * sampling_period

    # Create time array
    time_array = np.arange(0, total_time, sampling_period)

    # Plot each segment in red
    plt.figure(figsize=(14, 6))
    for i in range(0, len(time_series), window_size):
        segment_time = time_array[i:i + window_size]
        segment = time_series[i:i + window_size]
        plt.plot(segment_time, segment, color='blue')

    plt.title(f'Signal Segmentation with Window Size of 2048 pts ({variable_name})')
    plt.xlabel('Time (s)')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# Example usage
mat_file_path = '/content/drive/MyDrive/projet-sem/12k Drive End Bearing Fault Data/IR007_0.mat'
substitution_type = 'ba'
classification = 0
plot_segmentation_from_mat(mat_file_path, substitution_type, classification)
# Out:
# X105_BA_time series:
# [ 0.06466148 -0.02309626 -0.08852226 ...  0.09648926  0.08405591
#  -0.02015893]

# %% [markdown]
# FONCTION DE SEGMENTATION PARAMETRE CHEMEIN D'ACCES ET TYPE CAPTEUR BA,FE,DE classe 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from pprint import pprint

def plot_segmentation_from_mat(mat_file_path, substitution_type, classification):
    # Load the MATLAB file
    mat_contents = scipy.io.loadmat(mat_file_path)
    sub = substitution_type.upper()

    # Map classification to variable number
    if classification == 0:
        var_number = 169
    elif classification == 1:
        var_number = 170
    elif classification == 2:
        var_number = 171
    elif classification == 3:
        var_number = 172
    else:
        raise ValueError("Invalid classification. Supported values are 0, 1, 2, or 3.")

    # Access the variable using the substitution type and classification
    variable_name = f'X{var_number}_{sub}_time'
    time_data = mat_contents[variable_name]

    # Flatten the 2D array into a 1D numerical series
    time_series = np.ravel(time_data)

    # Print the numerical series
    print(f"{variable_name} series:")
    print(time_series)

    plt.figure(figsize=(10, 6))
    plt.plot(time_series)
    plt.title(f'{variable_name} Numerical Series')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

    # Parameters
    sampling_frequency = 51.2e3  # 51.2 kHz
    sampling_period = 1 / sampling_frequency  # 0.0000195313s
    window_size = 2048
    # Calculate the total time of the signal
    total_time = len(time_series) * sampling_period

    # Create time array
    time_array = np.arange(0, total_time, sampling_period)

    # Plot each segment in red
    plt.figure(figsize=(14, 6))
    for i in range(0, len(time_series), window_size):
        segment_time = time_array[i:i + window_size]
        segment = time_series[i:i + window_size]
        plt.plot(segment_time, segment, color='blue')

    plt.title(f'Signal Segmentation with Window Size of 2048 pts ({variable_name})')
    plt.xlabel('Time (s)')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# Example usage
mat_file_path = '/content/drive/MyDrive/projet-sem/12k Drive End Bearing Fault Data/IR014_0.mat'
substitution_type = 'ba'
classification = 0
plot_segmentation_from_mat(mat_file_path, substitution_type, classification)
# Out:
# X169_BA_time series:
# [-0.05544712 -0.03504677 -0.03379941 ... -0.03979478 -0.03182777
#   0.09318979]

# %% [markdown]
# FONCTION DE SEGMENTATION PARAMETRE CHEMEIN D'ACCES ET TYPE CAPTEUR BA,FE,DE classe 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

def plot_segmentation_from_mat(mat_file_path, substitution_type, classification):
    # Load the MATLAB file
    mat_contents = scipy.io.loadmat(mat_file_path)
    sub = substitution_type.upper()

    # Map classification to variable number
    if classification == 0:
        var_number = 209
    elif classification == 1:
        var_number = 210
    elif classification == 2:
        var_number = 211
    elif classification == 3:
        var_number = 212
    else:
        raise ValueError("Invalid classification. Supported values are 0, 1, 2, or 3.")

    # Access the variable using the substitution type and classification
    variable_name = f'X{var_number}_{sub}_time'
    time_data = mat_contents[variable_name]

    # Flatten the 2D array into a 1D numerical series
    time_series = np.ravel(time_data)

    # Print the numerical series
    print(f"{variable_name} series:")
    print(time_series)

    plt.figure(figsize=(10, 6))
    plt.plot(time_series)
    plt.title(f'{variable_name} Numerical Series')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

    # Parameters
    sampling_frequency = 51.2e3  # 51.2 kHz
    sampling_period = 1 / sampling_frequency  # 0.0000195313s
    window_size = 2048
    # Calculate the total time of the signal
    total_time = len(time_series) * sampling_period

    # Create time array
    time_array = np.arange(0, total_time, sampling_period)

    # Plot each segment in red
    plt.figure(figsize=(14, 6))
    for i in range(0, len(time_series) - window_size, window_size):
        segment_time = time_array[i:i + window_size]
        segment = time_series[i:i + window_size]
        plt.plot(segment_time, segment, color='blue')

    plt.title(f'Signal Segmentation with Window Size of 2048 pts ({variable_name})')
    plt.xlabel('Time (s)')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# Example usage
mat_file_path = '/content/drive/MyDrive/projet-sem/12k Drive End Bearing Fault Data/IR021_0.mat'
substitution_type = 'fe'
classification = 0
plot_segmentation_from_mat(mat_file_path, substitution_type, classification)
# Out:
# X209_FE_time series:
# [ 0.21572727 -0.03821455  0.04684364 ... -0.09348182 -0.29749818
#  -0.03246182]

# %% [markdown]
# FONCTION DE SEGMENTATION PARAMETRE CHEMEIN D'ACCES ET TYPE CAPTEUR BA,FE,DE classe 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

def plot_segmentation_from_mat(mat_file_path, substitution_type, classification):
    # Load the MATLAB file
    mat_contents = scipy.io.loadmat(mat_file_path)
    sub = substitution_type.upper()

    # Map classification to variable number
    if classification == 0:
        var_number = 130
    elif classification == 1:
        var_number = 131
    elif classification == 2:
        var_number = 132
    elif classification == 3:
        var_number = 133
    else:
        raise ValueError("Invalid classification. Supported values are 0, 1, 2, or 3.")

    # Access the variable using the substitution type and classification
    variable_name = f'X{var_number}_{sub}_time'
    time_data = mat_contents[variable_name]

    # Flatten the 2D array into a 1D numerical series
    time_series = np.ravel(time_data)

    # Print the numerical series
    print(f"{variable_name} series:")
    print(time_series)

    plt.figure(figsize=(10, 6))
    plt.plot(time_series)
    plt.title(f'{variable_name} Numerical Series')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

    # Parameters
    sampling_frequency = 51.2e3  # 51.2 kHz
    sampling_period = 1 / sampling_frequency  # 0.0000195313s
    window_size = 2048
    # Calculate the total time of the signal
    total_time = len(time_series) * sampling_period

    # Create time array
    time_array = np.arange(0, total_time, sampling_period)

    # Plot each segment in blue
    plt.figure(figsize=(14, 6))
    for i in range(0, len(time_series) - window_size, window_size):
        segment_time = time_array[i:i + window_size]
        segment = time_series[i:i + window_size]
        plt.plot(segment_time, segment, color='blue')  # Change color to blue

    plt.title(f'Signal Segmentation with Window Size of 2048 pts ({variable_name})')
    plt.xlabel('Time (s)')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# Example usage
mat_file_path = '/content/drive/MyDrive/projet-sem/12k Drive End Bearing Fault Data/OR007@6_1.mat'
substitution_type = 'fe'
classification = 1
plot_segmentation_from_mat(mat_file_path, substitution_type, classification)
# Out:
# X131_FE_time series:
# [-0.07745636  0.45528727 -0.21408364 ...  0.00472545  0.04581636
#  -0.05239091]
